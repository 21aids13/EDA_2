# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/weather_classification_data.csv")
df.head(30)
# Out:
#     Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0          14.0        73         9.5               82.0  partly cloudy
# 1          39.0        96         8.5               71.0  partly cloudy
# 2          30.0        64         7.0               16.0          clear
# 3          38.0        83         1.5               82.0          clear
# 4          27.0        74        17.0               66.0       overcast
# 5          32.0        55         3.5               26.0       overcast
# 6          -2.0        97         8.0               86.0       overcast
# 7           3.0        85         6.0               96.0  partly cloudy
# 8           3.0        83         6.0               66.0       overcast
# 9          28.0        74         8.5              107.0          clear
# 10         35.0        45         6.0               86.0  partly cloudy
# 11         38.0        43         2.0               16.0          clear
# ...

# %%
df.tail(30)
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 13170         30.0        60        17.0               86.0       overcast
# 13171          0.0        76         6.5               76.0       overcast
# 13172         33.0        54         0.5               15.0          clear
# 13173         15.0        66         8.0               59.0       overcast
# 13174         19.0        65         2.5               20.0  partly cloudy
# 13175         -6.0        87         9.0               97.0  partly cloudy
# 13176         19.0       100        36.0               86.0       overcast
# 13177         -3.0        94         8.0               50.0       overcast
# 13178          0.0        50        11.5               82.0         cloudy
# 13179         -4.0        98         1.5               76.0       overcast
# 13180         10.0        62        17.0               83.0  partly cloudy
# ...

# %%
df.loc[df['Cloud Cover'] == 'overcast','Cloud Cover'] = np.nan

# %%
df.isnull().sum()
# Out:
# Temperature                0
# Humidity                   0
# Wind Speed                 0
# Precipitation (%)          0
# Cloud Cover             6090
# Atmospheric Pressure       0
# UV Index                   0
# Season                     0
# Visibility (km)            0
# Location                   0
# Weather Type               0
# dtype: int64

# %%
df = df.dropna(subset=['Cloud Cover'])

# %%
df.isnull().sum()
# Out:
# Temperature             0
# Humidity                0
# Wind Speed              0
# Precipitation (%)       0
# Cloud Cover             0
# Atmospheric Pressure    0
# UV Index                0
# Season                  0
# Visibility (km)         0
# Location                0
# Weather Type            0
# dtype: int64
